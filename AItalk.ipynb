# %%
# #speech to text no talk from bot
import speech_recognition as sr
import pyttsx3
import pywhatkit
import datetime
import wikipedia
import pyjokes
import requests, json , sys
#PyAudio
#PyWhatKit
#PyJokes
#Wikipedia
#OpenweatherApi

listener = sr.Recognizer()
try:
    with sr.Microphone() as source:
            print("Start Speaking!!")
            voice = listener.listen(source)
            command = listener.recognize_google(voice)
            command = command.lower()
            if 'alexa' in command:
                command = command#.replace('alexa', '')
                print(command)
except:
    pass
# Out:
# Start Speaking!!
# alexa how are you

# %%
##bot talks in female voice
import speech_recognition as sr
import pyttsx3
import pywhatkit
import datetime
import wikipedia
import pyjokes
import requests, json , sys
#PyAudio
#PyWhatKit
#PyJokes
#Wikipedia
#OpenweatherApi

listener = sr.Recognizer()

voices = engine.getProperty("voices")        #voices[0] 0-->Male
engine.setProperty('voice', voices[0].id)               #1-->female


engine = pyttsx3.init()       ##bot talks in female voice
engine.say("I am Your Bot")
engine.say("Welcome Shivani ,How Can I help you?")
engine.runAndWait()


try:
    with sr.Microphone() as source:
            print("Start Speaking!!")
            voice = listener.listen(source)
            command = listener.recognize_google(voice)
            command = command.lower()
            if 'alexa' in command:
                command = command#.replace('alexa', '')
                print(command)
except:
    pass
# Out:
# Start Speaking!!

# %%
import speech_recognition as sr
import pyttsx3
import pywhatkit
import datetime
import wikipedia
import pyjokes
import requests, json , sys
#PyAudio
#PyWhatKit
#PyJokes
#Wikipedia
#OpenweatherApi

listener = sr.Recognizer()

engine = pyttsx3.init()

voices = engine.getProperty("voices")        #voices[0] 0-->Male
engine.setProperty('voice', voices[0].id)               #1-->female


def engine_talk(text):   #finddefined engine
    engine.say(text)
    engine.runAndWait()
    
    


def user_commands():
    try:
        with sr.Microphone() as source:
                print("Start Speaking!!")
                voice = listener.listen(source)
                command = listener.recognize_google(voice)
                command = command.lower()
                if 'alexa' in command:
                    command = command#.replace('alexa', '')
                    print(command)
    except:
        pass
    return command #must return 


def run_alexa():
    command= user_commands()
    if 'play' in command:         # if we say  play only
        engine_talk('Playing' +command) #playing  +command word which we say
    else:               #alexa play bts  play occurs so we should remove play word so next code
         engine_talk('I cant hear you')  # if not 
run_alexa()
# Out:
# Start Speaking!!
# alexa talk jay shri

# %%
import speech_recognition as sr
import pyttsx3
import pywhatkit
import datetime
import wikipedia
import pyjokes
import requests, json , sys
#PyAudio
#PyWhatKit
#PyJokes
#Wikipedia
#OpenweatherApi

listener = sr.Recognizer()

engine = pyttsx3.init()

voices = engine.getProperty("voices")        #voices[0] 0-->Male
engine.setProperty('voice', voices[0].id)               #1-->female


def engine_talk(text):   #finddefined engine
    engine.say(text)
    engine.runAndWait()
    
    


def user_commands():
    try:
        with sr.Microphone() as source:
                print("Start Speaking!!")
                voice = listener.listen(source)
                command = listener.recognize_google(voice)
                command = command.lower()
                if 'alexa' in command:
                    command = command.replace('alexa', '')  #to remove alexa replace()
                    print(command)
    except:
        pass
    return command #must return 


def run_alexa():
    command= user_commands()
    if 'play' in command:
        
        command= command.replace('play','')  #to remove play replace()
        print("New Command is "+command)
        
        print("The bot is telling us :Playing" +command)
        
        engine_talk('Playing' +command) #playing  +command word which we say
    else:               #alexa play bts  play occurs so we should remove play word so next code
         engine_talk('I cant hear you')  # if not 
run_alexa()
# Out:
# Start Speaking!!
#  play bts
# New Command is   bts
# The bot is telling us :Playing  bts

# %%
import speech_recognition as sr
import pyttsx3
import pywhatkit # whatap youtude inheriting
import datetime
import wikipedia
import pyjokes
import requests, json , sys
#PyAudio
#PyWhatKit
#PyJokes
#Wikipedia
#OpenweatherApi

listener = sr.Recognizer()

engine = pyttsx3.init()

voices = engine.getProperty("voices")        #voices[0] 0-->Male
engine.setProperty('voice', voices[0].id)               #1-->female


def engine_talk(text):   #finddefined engine
    engine.say(text)
    engine.runAndWait()
    
    


def user_commands():
    try:
        with sr.Microphone() as source:
                print("Start Speaking!!")
                voice = listener.listen(source)
                command = listener.recognize_google(voice)
                command = command.lower()
                if 'alexa' in command:
                    command = command.replace('alexa', '')  #to remove alexa replace()
                    print(command)
    except:
        pass
    return command #must return 


def run_alexa():
    command= user_commands()
    if 'play' in command:
        
        song = command.replace('play','')  #to remove play replace()
        #print("New Command is "+command)
        
        #print("The bot is telling us :Playing" +command)
        
        engine_talk('Playing' +song)#playing  +command word which we say
        
        pywhatkit.playonyt(song)      #plays youtubde songs
        
        
        
#        if 'play' in command:
#         song = command.replace('play', '')
#         #print('New Command is' +command)
#         #print('The bot is telling us: Playing' +command)
#         engine_talk('Playing' +song)
#         pywhatkit.playonyt(song)
        
        
        
    
    else:               #alexa play bts  play occurs so we should remove play word so next code
         engine_talk('I cant hear you')  # if not 
run_alexa()
# Out:
# Start Speaking!!
#  play bts

# %%
import speech_recognition as sr
import pyttsx3
import pywhatkit # whatap youtude inheriting
import datetime
import wikipedia
import pyjokes
import requests, json , sys
#PyAudio
#PyWhatKit
#PyJokes
#Wikipedia
#OpenweatherApi

listener = sr.Recognizer()

engine = pyttsx3.init()

voices = engine.getProperty("voices")        #voices[0] 0-->Male
engine.setProperty('voice', voices[0].id)               #1-->female


def engine_talk(text):   #finddefined engine
    engine.say(text)
    engine.runAndWait()
    
    


def user_commands():
    try:
        with sr.Microphone() as source:
                print("Start Speaking!!")
                voice = listener.listen(source)
                command = listener.recognize_google(voice)
                command = command.lower()
                if 'alexa' in command:
                    command = command.replace('alexa', '')  #to remove alexa replace()
                    print(command)
    except:
        pass
    return command #must return 


def run_alexa():
    command= user_commands()
    if 'play' in command:
        
        song = command.replace('play','')  #to remove play replace()
        #print("New Command is "+command)
        
        #print("The bot is telling us :Playing" +command)
        
        engine_talk('Playing' +song)#playing  +command word which we say
        
        pywhatkit.playonyt(song)      #plays youtubde songs
        
        
        
    elif 'time' in command:
        time = datetime.datetime.now().strftime('%I:%M %p')  #says right current time
        engine_talk('The current time is' +time)
        

        
        
    
    else:               #alexa play bts  play occurs so we should remove play word so next code
         engine_talk('I cant hear you')  # if not 
run_alexa()
# Out:
# Start Speaking!!
#  what is the right time

# %%
import speech_recognition as sr
import pyttsx3
import pywhatkit # whatap youtude inheriting
import datetime
import wikipedia
import pyjokes
import requests, json , sys
#PyAudio
#PyWhatKit
#PyJokes
#Wikipedia
#OpenweatherApi

listener = sr.Recognizer()

engine = pyttsx3.init()

voices = engine.getProperty("voices")        #voices[0] 0-->Male
engine.setProperty('voice', voices[0].id)               #1-->female


def engine_talk(text):   #finddefined engine
    engine.say(text)
    engine.runAndWait()
    
    


def user_commands():
    try:
        with sr.Microphone() as source:
                print("Start Speaking!!")
                voice = listener.listen(source)
                command = listener.recognize_google(voice)
                command = command.lower()
                if 'alexa' in command:
                    command = command.replace('alexa', '')  #to remove alexa replace()
                    print(command)
    except:
        pass
    return command #must return 


def run_alexa():
    command= user_commands()
    if 'play' in command:
        
        song = command.replace('play','')  #to remove play replace()
        #print("New Command is "+command)
        
        #print("The bot is telling us :Playing" +command)
        
        engine_talk('Playing' +song)#playing  +command word which we say
        
        pywhatkit.playonyt(song)      #plays youtubde songs
        
        
        
    elif 'time' in command:
        time = datetime.datetime.now().strftime('%I:%M %p')  #says right current time
        engine_talk('The current time is' +time)
        
        
    elif 'who is' in command:
        name = command.replace('who is' , '')
        info =  wikipedia.summary(name, 0)
        print(info)
        engine_talk(info)
        

        
        
    
    else:               #alexa play bts  play occurs so we should remove play word so next code
         engine_talk('I cant hear you')  # if not 
run_alexa()
# Out:
# Start Speaking!!
#  who is shahrukh khan
# Shah Rukh Khan (pronounced [ˈʃɑːɦɾʊx xɑːn]; born 2 November 1965), also known by the initialism SRK, is an Indian actor, film producer, and television personality who works in Hindi films. Referred to in the media as the "Baadshah of Bollywood", "King of Bollywood" and "King Khan", he has appeared in more than 80 films, and earned numerous accolades, including 14 Filmfare Awards. He has been awarded the Padma Shri by the Government of India, as well as the Ordre des Arts et des Lettres and Legion of Honour by the Government of France. Khan has a significant following in Asia and the Indian diaspora worldwide. In terms of audience size and income, he has been described as one of the most successful film stars in the world.
# ...

# %%
import speech_recognition as sr
import pyttsx3
import pywhatkit # whatap youtude inheriting
import datetime
import wikipedia
import pyjokes
import requests, json , sys
#PyAudio
#PyWhatKit
#PyJokes
#Wikipedia
#OpenweatherApi

listener = sr.Recognizer()

engine = pyttsx3.init()

voices = engine.getProperty("voices")        #voices[0] 0-->Male
engine.setProperty('voice', voices[0].id)               #1-->female


def engine_talk(text):   #finddefined engine
    engine.say(text)
    engine.runAndWait()
    
    


def user_commands():
    try:
        with sr.Microphone() as source:
                print("Start Speaking!!")
                voice = listener.listen(source)
                command = listener.recognize_google(voice)
                command = command.lower()
                if 'alexa' in command:
                    command = command.replace('alexa', '')  #to remove alexa replace()
                    print(command)
    except:
        pass
    return command #must return 


def run_alexa():
    command= user_commands()
    if 'play' in command:
        
        song = command.replace('play','')  #to remove play replace()
        #print("New Command is "+command)
        
        #print("The bot is telling us :Playing" +command)
        
        engine_talk('Playing' +song)#playing  +command word which we say
        
        pywhatkit.playonyt(song)      #plays youtubde songs
        
        
        
    elif 'time' in command:
        time = datetime.datetime.now().strftime('%I:%M %p')  #says right current time
        engine_talk('The current time is' +time)
        
        
    elif 'who is' in command:
        name = command.replace('who is' , '')
        info =  wikipedia.summary(name, 0)
        print(info)
        engine_talk(info)
        
    elif 'what is' in command:
        name = command.replace('what is' , '')
        info =  wikipedia.summary(name, 0)
        print(info)
        engine_talk(info)
        
    elif 'joke' in command:
        engine_talk(pyjokes.get_joke())
    
    elif 'weather' in command:
        engine_talk('Please tell the name of the city')
        city = user_commands()
        #weather_api = weather('Hong Kong')
        weather_api = weather(city)
        engine_talk(weather_api + 'degree fahreneit' )
    elif 'stop' in command:
        sys.exit()
#     else:
#         engine_talk('I could not hear you properly')
        

        
        
    
    else:               #alexa play bts  play occurs so we should remove play word so next code
         engine_talk('I cant hear you')  # if not 
run_alexa()
# Out:
# Start Speaking!!
#  what is pizza
# Pizza (English:  PIT-zə, Italian: [ˈpittsa], Neapolitan: [ˈpittsə]) is a dish of  Italian origin consisting of a usually round, flat base of leavened wheat-based dough topped with tomatoes, cheese, and often various other ingredients (such as various types of sausage, anchovies, mushrooms, onions, olives, vegetables, meat, ham, etc.), which is then baked at a high temperature, traditionally in a wood-fired oven. A small pizza is sometimes called a pizzetta. A person who makes pizza is known as a pizzaiolo.
# In Italy, pizza served in a restaurant is presented unsliced, and is eaten with the use of a knife and fork. In casual settings, however, it is cut into wedges to be eaten while held in the hand.
# ...

# %%
import speech_recognition as sr
import pyttsx3
import pywhatkit # whatap youtude inheriting
import datetime
import wikipedia
import pyjokes
import requests, json , sys     ##WEATHER TELLING ALEXA
#PyAudio
#PyWhatKit
#PyJokes
#Wikipedia
#OpenweatherApi

listener = sr.Recognizer()

engine = pyttsx3.init()

voices = engine.getProperty("voices")        #voices[0] 0-->Male
engine.setProperty('voice', voices[0].id)               #1-->female


def engine_talk(text):   #finddefined engine
    engine.say(text)
    engine.runAndWait()
    

def weather(city):
    # Enter your API key here 
    api_key = "22ef7658482814e1e897c4ab9388e156"                        #"<YOUR API KEY"
    
    # base_url variable to store url 
    base_url = "http://api.openweathermap.org/data/2.5/weather?"

    # Give city name 
    city_name = city
    
    # complete_url variable to store 
    # complete url address 
    complete_url = base_url + "appid=" + api_key + "&q=" + city_name 
    
    # get method of requests module 
    # return response object 
    response = requests.get(complete_url) 
    
    # json method of response object  
    # convert json format data into 
    # python format data 
    x = response.json() 
    
    # Now x contains list of nested dictionaries 
    # Check the value of "cod" key is equal to 
    # "404", means city is found otherwise, 
    # city is not found 
    if x["cod"] != "404": 
    
        # store the value of "main" 
        # key in variable y 
        y = x["main"] 
    
        # store the value corresponding 
        # to the "temp" key of y 
        current_temperature = y["temp"] 
    
        # store the value corresponding 
        # to the "pressure" key of y 
        #current_pressure = y["pressure"] 
    
        # store the value corresponding 
        # to the "humidity" key of y 
        #current_humidiy = y["humidity"] 
    
        # store the value of "weather" 
        # key in variable z 
        #z = x["weather"] 
    
        # store the value corresponding  
        # to the "description" key at  
        # the 0th index of z 
        #weather_description = z[0]["description"]
        return str(current_temperature)
    
    


def user_commands():
    try:
        with sr.Microphone() as source:
                print("Start Speaking!!")
                voice = listener.listen(source)
                command = listener.recognize_google(voice)
                command = command.lower()
                if 'alexa' in command:
                    command = command.replace('alexa', '')  #to remove alexa replace()
                    print(command)
    except:
        pass
    return command #must return 


def run_alexa():
    command= user_commands()
    if 'play' in command:
        
        song = command.replace('play','')  #to remove play replace()
        #print("New Command is "+command)
        
        #print("The bot is telling us :Playing" +command)
        
        engine_talk('Playing' +song)#playing  +command word which we say
        
        pywhatkit.playonyt(song)      #plays youtubde songs
        
        
        
    elif 'time' in command:
        time = datetime.datetime.now().strftime('%I:%M %p')  #says right current time
        engine_talk('The current time is' +time)
        
        
    elif 'who is' in command:
        name = command.replace('who is' , '')
        info =  wikipedia.summary(name, 0)
        print(info)
        engine_talk(info)
        
    elif 'what is' in command:
        name = command.replace('what is' , '')
        info =  wikipedia.summary(name, 0)      
        print(info)
        engine_talk(info)
        
    elif 'joke' in command:
        engine_talk(pyjokes.get_joke())
                                         # when what is  weather tother used then 
                                              #it gives preferences to first if statement  
    elif 'weather' in command:
        engine_talk('Please tell the name of the city')  
        city = user_commands()
        #weather_api = weather('Hong Kong')
        weather_api = weather(city)
        engine_talk(weather_api + 'degree fahreneit' )
    elif 'stop' in command:
        sys.exit()
#     else:
#         engine_talk('I could not hear you properly')
        

        
        
    
    else:               #alexa play bts  play occurs so we should remove play word so next code
         engine_talk('I cant hear you')  # if not 
run_alexa()
# Out:
# Start Speaking!!
#  what is the weather in hong kong
# Hong Kong (US:  or UK: ; Chinese: 香港, Cantonese: [hœ́ːŋ.kɔ̌ːŋ] (listen)), officially the Hong Kong Special Administrative Region of the People's Republic of China (abbr. Hong Kong SAR or HKSAR), is a city and special administrative region of China on the eastern Pearl River Delta in South China. With 7.5 million residents of various nationalities in a 1,104-square-kilometre (426 sq mi) territory, Hong Kong is one of the most densely populated places in the world. Hong Kong is also a major global financial centre and one of the most developed cities in the world.
# ...

# %%
#Importing Libraries
import speech_recognition as sr
import pyttsx3
import pywhatkit
import datetime
import wikipedia
import pyjokes
import requests, json , sys
#PyAudio
#PyWhatKit
#PyJokes
#Wikipedia
#OpenweatherApi

listener = sr.Recognizer()

engine = pyttsx3.init()
voices = engine.getProperty("voices")
engine.setProperty('voice', voices[1].id)

def engine_talk(text):
    engine.say(text)
    engine.runAndWait()
    
def weather(city):
    # Enter your API key here 
    api_key = "22ef7658482814e1e897c4ab9388e156"               #"<YOUR API KEY"
    
    # base_url variable to store url 
    base_url = "http://api.openweathermap.org/data/2.5/weather?"

    # Give city name 
    city_name = city
    
    # complete_url variable to store 
    # complete url address 
    complete_url = base_url + "appid=" + api_key + "&q=" + city_name 
    
    # get method of requests module 
    # return response object 
    response = requests.get(complete_url) 
    
    # json method of response object  
    # convert json format data into 
    # python format data 
    x = response.json() 
    
    # Now x contains list of nested dictionaries 
    # Check the value of "cod" key is equal to 
    # "404", means city is found otherwise, 
    # city is not found 
    if x["cod"] != "404": 
    
        # store the value of "main" 
        # key in variable y 
        y = x["main"] 
    
        # store the value corresponding 
        # to the "temp" key of y 
        current_temperature = y["temp"] 
    
        # store the value corresponding 
        # to the "pressure" key of y 
        #current_pressure = y["pressure"] 
    
        # store the value corresponding 
        # to the "humidity" key of y 
        #current_humidiy = y["humidity"] 
    
        # store the value of "weather" 
        # key in variable z 
        #z = x["weather"] 
    
        # store the value corresponding  
        # to the "description" key at  
        # the 0th index of z 
        #weather_description = z[0]["description"]
        return str(current_temperature)
    
        # print following values 
        '''print(" Temperature (in kelvin unit) = " +
                        str(current_temperature) + 
            "\n atmospheric pressure (in hPa unit) = " +
                        str(current_pressure) +
            "\n humidity (in percentage) = " +
                        str(current_humidiy) +
            "\n description = " +
                        str(weather_description)) 
    else: 
        print(" City Not Found ")
        '''

def user_commands():
    try:
        with sr.Microphone() as source:
            print("Start Speaking!!")
            voice = listener.listen(source)
            command = listener.recognize_google(voice)
            command = command.lower()
            if 'alexa' in command:
                command = command.replace('alexa', '')
                print(command)
    except:
        pass
    return command
    
    
def run_alexa():
    command = user_commands()
    if 'play' in command:
        song = command.replace('play', '')
        #print('New Command is' +command)
        #print('The bot is telling us: Playing' +command)
        engine_talk('Playing' +song)
        pywhatkit.playonyt(song)
    elif 'time' in command:
        time = datetime.datetime.now().strftime('%I:%M %p')
        engine_talk('The current time is' +time)
    elif 'who is' in command:
        name = command.replace('who is' , '')
        info =  wikipedia.summary(name, 1)
        print(info)
        engine_talk(info)
    elif 'joke' in command:
        engine_talk(pyjokes.get_joke())
    elif 'weather' in command:
        engine_talk('Please tell the name of the city')
        city = user_commands()
        #weather_api = weather('Hong Kong')
        weather_api = weather(city)#not telling city weather
        engine_talk(weather_api + 'degree fahreneit' )
    elif 'stop' in command:
        sys.exit()
    else:
        engine_talk('I could not hear you properly')
        
        
while True:
    run_alexa()
# Out:
# Start Speaking!!
# Start Speaking!!
# Start Speaking!!
#  can you say me a joke
# Start Speaking!!
# Start Speaking!!
# okay  what is no no stop enough
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
